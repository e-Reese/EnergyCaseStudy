# %%
#Import libraries
import json
import gzip
import pandas as pd

# %%
# Importing electricity sales data
elec_sales_df = pd.read_json('source_data/ElectricitySales_2023_AllSectorsMinusTrans.json', orient='records', dtype=False)

# %%
elec_sales_df.head()
# Out:
#   period stateid stateDescription sectorid   sectorName customers  price  \
# 0   2023      AK           Alaska      ALL  all sectors    357119  21.39
# 1   2023      AK           Alaska      RES  residential    298426  23.89
# 2   2023      AK           Alaska      OTH        other       NaN    NaN
# 3   2023      AK           Alaska      IND   industrial      1183  18.74
# 4   2023      AK           Alaska      COM   commercial     57510  20.81
#
#       revenue       sales      customers-units             price-units  \
# 0  1283.90142  6003.63966  number of customers  cents per kilowatthour
# 1   488.93037  2046.18113  number of customers  cents per kilowatthour
# 2         NaN         NaN  number of customers  cents per kilowatthour
# 3   259.18168  1382.99739  number of customers  cents per kilowatthour
# 4   535.78938  2574.46114  number of customers  cents per kilowatthour
#
#      revenue-units            sales-units
# 0  million dollars  million kilowatthours
# ...

# %%
elec_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   period            310 non-null    object
#  1   stateid           310 non-null    object
#  2   stateDescription  310 non-null    object
#  3   sectorid          310 non-null    object
#  4   sectorName        310 non-null    object
#  5   customers         248 non-null    object
#  6   price             248 non-null    object
#  7   revenue           248 non-null    object
#  8   sales             248 non-null    object
#  9   customers-units   310 non-null    object
#  10  price-units       310 non-null    object
#  11  revenue-units     310 non-null    object
#  12  sales-units       310 non-null    object
# dtypes: object(13)
# memory usage: 31.6+ KB

# %%
# Importing electicity generation data
elec_gen_df = pd.read_json('source_data/ElectricityGenFuelTypes_State-Monthly-2023.json', orient='records')

# %%
elec_gen_df.head()
# Out:
#     period location stateDescription  sectorid sectorDescription fueltypeid  \
# 0  2023-01       AK           Alaska        99       All Sectors        COW
# 1  2023-01       AK           Alaska        99       All Sectors        AOR
# 2  2023-01       AK           Alaska        99       All Sectors        ALL
# 3  2023-01       AK           Alaska        99       All Sectors        REN
# 4  2023-01       AK           Alaska        99       All Sectors        PET
#
#   fuelTypeDescription  consumption-for-eg consumption-for-eg-units  \
# 0   all coal products              44.714      thousand short tons
# 1      all renewables               0.000  thousand physical units
# 2           all fuels               0.000  thousand physical units
# 3           renewable              64.657  thousand physical units
# 4           petroleum             151.182         thousand barrels
#
#    consumption-for-eg-btu  ... receipts           receipts-units receipts-btu  \
# ...

# %%
# Exporting the datas
elec_sales_df.to_csv('output_data/ElectricitySales_Monthly_2023.csv')
elec_gen_df.to_csv('output_data/ElectricityGen_Monthly_2023.csv')
